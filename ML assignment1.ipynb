# %% [markdown]
# # You are given house_price.csv which contains property prices in the city of Bangalore. You need to examine price per square feet do the following:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Q1. Perform basic EDA (Score:1)

# %%
df1=pd.read_csv("house_price.csv")
df=df1.copy()
df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
df.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#    price_per_sqft
# 0            3699
# 1            4615
# 2            4305
# 3            6245
# 4            4250

# %%
df.tail()
# Out:
#                     location       size  total_sqft  bath  price  bhk  \
# 13195             Whitefield  5 Bedroom      3453.0   4.0  231.0    5
# 13196                  other      4 BHK      3600.0   5.0  400.0    4
# 13197  Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.0    2
# 13198        Padmanabhanagar      4 BHK      4689.0   4.0  488.0    4
# 13199           Doddathoguru      1 BHK       550.0   1.0   17.0    1
#
#        price_per_sqft
# 13195            6689
# 13196           11111
# 13197            5258
# 13198           10407
# 13199            3090

# %%
df.info
# Out:
# <bound method DataFrame.info of                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# ...

# %%
df.describe()
# Out:
#          total_sqft          bath         price           bhk  price_per_sqft
# count  13200.000000  13200.000000  13200.000000  13200.000000    1.320000e+04
# mean    1555.302783      2.691136    112.276178      2.800833    7.920337e+03
# std     1237.323445      1.338915    149.175995      1.292843    1.067272e+05
# min        1.000000      1.000000      8.000000      1.000000    2.670000e+02
# 25%     1100.000000      2.000000     50.000000      2.000000    4.267000e+03
# 50%     1275.000000      2.000000     71.850000      3.000000    5.438000e+03
# 75%     1672.000000      3.000000    120.000000      3.000000    7.317000e+03
# max    52272.000000     40.000000   3600.000000     43.000000    1.200000e+07

# %%
df.shape
# Out:
# (13200, 7)

# %%
#Checking for null values
df.isnull().sum()
# Out:
# location          0
# size              0
# total_sqft        0
# bath              0
# price             0
# bhk               0
# price_per_sqft    0
# dtype: int64

# %%
#Checking for duplicates
print("Total number of duplicate raws:",df.duplicated().sum())
# Out:
# Total number of duplicate raws: 1049

# %%
#Remove duplicates
df.drop_duplicates()
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13194         Green Glen Layout      3 BHK      1715.0   3.0  112.00    3
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
#Checking for Datatypes
df.dtypes
# Out:
# location           object
# size               object
# total_sqft        float64
# bath              float64
# price             float64
# bhk                 int64
# price_per_sqft      int64
# dtype: object

# %%
# Box plot for outlier detection
plt.figure(figsize=(10, 6))
sns.boxplot(data=df)
plt.show()

# %% [markdown]
# ### price_per_sqft has oulliers

# %% [markdown]
# # Q2: Detect Outliers and Remove Them (Score: 4)

# %% [markdown]
# ## a) Mean and Standard deviation

# %%
# Define threshold
n = 3  # Number of standard deviations
mean = df['price_per_sqft'].mean()
std_dev = df['price_per_sqft'].std()
print('Mean:',mean)
print('std deviation:',std_dev)
# Out:
# Mean: 7920.336742424242
# std deviation: 106727.16032810845

# %%
# Define boundaries
lower_limit = mean - n * std_dev
upper_limit = mean + n * std_dev
print("lower_limit:",lower_limit)
print("Upper limit:",upper_limit)
# Out:
# lower_limit: -312261.1442419011
# Upper limit: 328101.8177267496

# %%
# Remove outliers using trimming
df_trimmed = df[(df['price_per_sqft'] >= lower_limit) & (df['price_per_sqft'] <= upper_limit)]
df_trimmed
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
# Remove outliers using capping
R=df['price_per_sqft'] = np.clip(df['price_per_sqft'], lower_limit, upper_limit)
R
# Out:
# 0         3699.0
# 1         4615.0
# 2         4305.0
# 3         6245.0
# 4         4250.0
#           ...
# 13195     6689.0
# 13196    11111.0
# 13197     5258.0
# 13198    10407.0
# 13199     3090.0
# Name: price_per_sqft, Length: 13200, dtype: float64

# %% [markdown]
# ## b)Percentile method

# %%
df2=df1.copy()

# %%
df2.shape
# Out:
# (13200, 7)

# %%
# Define percentiles
lower_percentile = df2['price_per_sqft'].quantile(0.01)
upper_percentile = df2['price_per_sqft'].quantile(0.99)
print('Lower percentile:',lower_percentile)
print('Upper percentile',upper_percentile)
# Out:
# Lower percentile: 2549.0
# Upper percentile 23674.45000000001

# %%
# Remove outliers using trimming
df_trimmed = df2[(df2['price_per_sqft'] >= lower_percentile) & (df2['price_per_sqft'] <= upper_percentile)]
df_trimmed
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
# Remove outliers using capping
R=df2['price_per_sqft'] = np.clip(df2['price_per_sqft'], lower_percentile, upper_percentile)
# Out:
# 0         3699.0
# 1         4615.0
# 2         4305.0
# 3         6245.0
# 4         4250.0
#           ...
# 13195     6689.0
# 13196    11111.0
# 13197     5258.0
# 13198    10407.0
# 13199     3090.0
# Name: price_per_sqft, Length: 13200, dtype: float64

# %% [markdown]
# ## c) IQR(Inter quartile range method)

# %%
df3=df1.copy()

# %%
df3.shape
# Out:
# (13200, 7)

# %%
# Calculate Q1, Q3, and IQR
Q1 = df3['price_per_sqft'].quantile(0.25)
Q3 = df3['price_per_sqft'].quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# 3050.0

# %%
# Define bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
print('Lower bound',lower_bound)
print('Upper bound',upper_bound)
# Out:
# Lower bound -308.0
# Upper bound 11892.0

# %%
# Remove outliers using trimming
df_trimmed = df3[(df3['price_per_sqft'] >= lower_bound) & (df3['price_per_sqft'] <= upper_bound)]
df_trimmed
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
# Remove outliers using capping
df3['price_per_sqft'] = np.clip(df3['price_per_sqft'], lower_bound, upper_bound)

# %% [markdown]
# ## d) Z Score method

# %%
from scipy.stats import zscore

# %%
df4=df1.copy()

# %%
df4.shape
# Out:
# (13200, 7)

# %%
# Calculate Z-scores
Z=df4['z_score'] = zscore(df4['price_per_sqft'])

Z
# Out:
# 0       -0.395526
# 1       -0.280012
# 2       -0.319105
# 3       -0.074459
# 4       -0.326041
#            ...
# 13195   -0.018468
# 13196    0.539174
# 13197   -0.198926
# 13198    0.450396
# 13199   -0.472325
# Name: price_per_sqft, Length: 13200, dtype: float64

# %%
# Remove outliers using trimming
df_trimmed = df4[abs(df4['z_score']) <= 3]
df_trimmed.shape
# Out:
# (13156, 8)

# %%
df_trimmed.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#    price_per_sqft   z_score
# 0          3699.0 -0.395526
# 1          4615.0 -0.280012
# 2          4305.0 -0.319105
# 3          6245.0 -0.074459
# 4          4250.0 -0.326041

# %%
# Remove outliers using capping
df4['price_per_sqft'] = np.where(df4['z_score'] > 3, mean + 3 * std_dev, 
                             np.where(df4['z_score'] < -3, mean - 3 * std_dev, df4['price_per_sqft']))
df4['price_per_sqft']
# Out:
# 0         3699.0
# 1         4615.0
# 2         4305.0
# 3         6245.0
# 4         4250.0
#           ...
# 13195     6689.0
# 13196    11111.0
# 13197     5258.0
# 13198    10407.0
# 13199     3090.0
# Name: price_per_sqft, Length: 13200, dtype: float64

# %%
z_filtered = df[np.abs(z_scores) <= 3]
z_filtered
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0              3699.0
# 1              4615.0
# ...

# %% [markdown]
# # Q3. Create a box plot and use this to determine which method seems to work best to remove outliers for this data? (Score:1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import zscore

# Assuming `df` is the DataFrame and 'price_per_sqft' is the column of interest

# Original Data
#original_data = df['price_per_sqft']

# Mean ± Std Dev Method
n = 3  # Number of standard deviations to consider
mean = original_data.mean()
std_dev = original_data.std()
lower_limit = mean - n * std_dev
upper_limit = mean + n * std_dev
df_trimmed1 = original_data[(original_data >= lower_limit) & (original_data <= upper_limit)]

# Percentile Method
lower_percentile = original_data.quantile(0.01)
upper_percentile = original_data.quantile(0.99)
df_trimmed2 = original_data[(original_data >= lower_percentile) & (original_data <= upper_percentile)]

# IQR Method
Q1 = original_data.quantile(0.25)
Q3 = original_data.quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR
df_trimmed3 = original_data[(original_data >= lower_bound) & (original_data <= upper_bound)]

# Z-Score Method
z_scores = zscore(original_data)
df_trimmed4 = original_data[(np.abs(z_scores) <= 3)]

# Plotting the boxplots
data_to_plot = [ df_trimmed1, df_trimmed2, df_trimmed3, df_trimmed4]
labels = [ 'Mean ± 3*StdDev', 'Percentile', 'IQR', 'Z-Score']

plt.figure(figsize=(12, 6))
plt.boxplot(data_to_plot, labels=labels, patch_artist=True, showmeans=True)
plt.title('Box Plot of price_per_sqft - Original and Outlier Removed Data')
plt.ylabel('Price per Square Foot')
plt.xticks(rotation=15)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ## Here IQR method seems to be the best one

# %% [markdown]
# # 4. Draw histplot to check the normality of the column(price per sqft column) and perform transformations if needed. Check the skewness and kurtosis before and after the transformation. (Score:1)

# %%
import seaborn as sns
from scipy.stats import kurtosis, skew

# Original Data
original_data = df['price_per_sqft']

# Calculate Skewness and Kurtosis
original_skewness = skew(original_data)
original_kurtosis = kurtosis(original_data)

# Plot Histogram for Original Data
plt.figure(figsize=(12, 6))
sns.histplot(original_data, kde=True, bins=30, color='maroon')
plt.title(f'Original Data Distribution (Skewness: {original_skewness:.2f}, Kurtosis: {original_kurtosis:.2f})')
plt.xlabel('Price per Square Foot')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# Apply Log Transformation
transformed_data = np.log1p(original_data)  # Log transformation to handle zero/negative values

# Calculate Skewness and Kurtosis for Transformed Data
transformed_skewness = skew(transformed_data)
transformed_kurtosis = kurtosis(transformed_data)

# Plot Histogram for Transformed Data
plt.figure(figsize=(12, 6))
sns.histplot(transformed_data, kde=True, bins=30, color='orange')
plt.title(f'Transformed Data Distribution (Skewness: {transformed_skewness:.2f}, Kurtosis: {transformed_kurtosis:.2f})')
plt.xlabel('Log-Transformed Price per Square Foot')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# Print Skewness and Kurtosis Values
print(f"Original Data: Skewness = {original_skewness:.2f}, Kurtosis = {original_kurtosis:.2f}")
print(f"Transformed Data: Skewness = {transformed_skewness:.2f}, Kurtosis = {transformed_kurtosis:.2f}")
# Out:
# Original Data: Skewness = 27.61, Kurtosis = 1062.58
# Transformed Data: Skewness = 1.05, Kurtosis = 3.45

# %% [markdown]
# # Q5. Check the correlation between all the numerical columns and plot heatmap. (Score:1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select relevant numerical columns
numerical_columns = ['total_sqft', 'bath', 'price', 'bhk', 'price_per_sqft']

# Calculate the correlation matrix
correlation_matrix = df[numerical_columns].corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap of Numerical Variables')
plt.show()

# %% [markdown]
# # Q6. Draw Scatter plot between the variables to check the correlation between them. (Score:1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select relevant numerical columns
numerical_columns = ['total_sqft', 'bath', 'price', 'bhk', 'price_per_sqft']

# Set the figure size
plt.figure(figsize=(12, 10))

# Create scatter plots for all pairs of numerical columns
sns.pairplot(df[numerical_columns])

# Show the plot
plt.suptitle('Scatter Plots for Correlation between Variables', y=1.02)
plt.show()
